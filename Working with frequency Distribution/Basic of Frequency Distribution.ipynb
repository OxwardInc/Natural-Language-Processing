# %%
from nltk import ConditionalFreqDist, FreqDist

# %%
s = 'I saw Sussie sitting in a shoe shine shop. Where she sits she shines, and where she shines she sits.'

# %%
l = s.split()

# %%
l
# Out:
# ['I',
#  'saw',
#  'Sussie',
#  'sitting',
#  'in',
#  'a',
#  'shoe',
#  'shine',
#  'shop.',
#  'Where',
#  'she',
#  'sits',
#  'she',
#  'shines,',
#  'and',
#  'where',
#  'she',
#  'shines',
#  'she',
#  'sits.']

# %%
fd = FreqDist(l)

# %%
fd
# Out:
# FreqDist({'she': 4, 'I': 1, 'saw': 1, 'Sussie': 1, 'sitting': 1, 'in': 1, 'a': 1, 'shoe': 1, 'shine': 1, 'shop.': 1, ...})

# %%
fd.most_common(2)
# Out:
# [('she', 4), ('I', 1)]

# %%
from nltk.corpus import brown

# %%
l_w_humor = brown.words(categories='humor')

# %%
len(l_w_humor)
# Out:
# 21695

# %%
fd_w_humor = FreqDist(l_w_humor)

# %%
fd_w_humor.most_common(10)
# Out:
# [(',', 1331),
#  ('the', 930),
#  ('.', 877),
#  ('of', 515),
#  ('and', 512),
#  ('a', 505),
#  ('to', 463),
#  ('``', 343),
#  ("''", 340),
#  ('in', 334)]

# %%
fd_w_humor.hapaxes()
# Out:
# ['Hinkle',
#  'fancying',
#  'marriages',
#  'listed',
#  'Mormon',
#  'Beard',
#  'instigation',
#  'fourth',
#  'victim',
#  'beard',
#  'secured',
#  'report',
#  'trail',
#  'Cal',
#  'gas',
#  'main',
#  'boulevards',
#  'attendants',
#  'Ye',
#  'Olde',
#  'Gasse',
#  'Filling',
#  'Station',
#  'Avocado',
#  'Avenue',
#  'paused',
#  'route',
#  'Diego',
#  'headed',
#  'direction',
#  'Juan',
#  'Capistrano',
#  'By-the-Sea',
#  'quaint',
#  'Spanish',
#  'Mission',
#  'Drive-in',
#  'eating',
#  'tamale',
#  'convertible',
#  'quest',
#  'stolen',
#  'rug',
#  'robe',
#  'pawnshop',
#  'Glendale',
#  'placed',
#  'informing',
#  'questioning',
#  'apprehended',
#  'larceny',
#  'suspect',
#  'murders',
#  'uncovered',
#  'meaningless',
#  'phrases',
#  'souls',
#  'detective',
#  'commenting',
#  'behavior',
#  'myriad',
#  'citizens',
#  'community',
#  'mentally',
#  'unhinged',
#  'harmless',
#  'awaiting',
#  'failed',
#  'endeavoring',
#  'wrists',
#  'fainted',
#  'sight',
#  'blood',
#  'authorities',
#  'significance',
#  'episode',
#  'offered',
#  'whisky',
#  'lifelong',
#  'teetotaler',
#  'vaulting',
#  'mayorship',
#  'escaped',
#  'possibly',
#  'thief',
#  'attempted',
#  'guilty',
#  'breaking',
#  'laws',
#  'opportunity',
#  'test',
#  'chat',
#  'stating',
#  "we've",
#  'goods',
#  "It'll",
#  'shifty',
#  'relentless',
#  'pursuit',
#  'confessing',
#  'dreamed',
#  'summoned',
#  'officials',
#  'chagrin',
#  'pooh-poohed',
#  'credulity',
#  'required',
#  'strength',
#  'bravado',
#  'daring',
#  'commit',
#  'Ridiculous',
#  'glint',
#  'lit',
#  'stiffened',
#  'rose',
#  "He'd",
#  'queried',
#  'murdering',
#  "there's",
#  'derision',
#  'organized',
#  'termed',
#  'Wild',
#  'Goose',
#  'Chase',
#  'incredible',
#  'committing',
#  'consisted',
#  'reporters',
#  'cameramen',
#  'matter-of-factness',
#  'attitude',
#  'directed',
#  'cortege',
#  'autos',
#  'Santa',
#  'Monica',
#  'Stopping',
#  'cars',
#  'fork',
#  'spot',
#  'shrub-covered',
#  'hills',
#  'indicated',
#  'Orders',
#  'dig',
#  'chortled',
#  'cracked',
#  'quibs',
#  'gibes',
#  'digging',
#  'edge',
#  'remarking',
#  'picnic',
#  'Said',
#  'Joking',
#  'gathered',
#  'thrusting',
#  'view',
#  'package',
#  'crudely',
#  "murderer's",
#  'sport',
#  'shirts',
#  'fragment',
#  "victim's",
#  'wild',
#  'elation',
#  'disclosures',
#  'reward',
#  'procedure',
#  'Justice',
#  'triumph',
#  'cahoots',
#  'drag',
#  'sensation',
#  'Every',
#  'scandal',
#  'copy',
#  "Marshall's",
#  'pen',
#  'cynics',
#  'impatience',
#  'dramatic',
#  'devilish',
#  'cleverness',
#  'Multiple',
#  'Romances',
#  'Addict',
#  'Downfall',
#  'Film',
#  'Idol',
#  'willing',
#  "mayor's",
#  'throne',
#  'studied',
#  'thwarted',
#  'sensed',
#  'overvaulting',
#  'desire',
#  'consciousness',
#  'entertained',
#  'aspirations',
#  'favors',
#  'luckier',
#  'chap',
#  'tracked',
#  'cocktail',
#  'downtown',
#  'urged',
#  'attend',
#  'gentlemen',
#  'majority',
#  'smoke',
#  'bottles',
#  'guests',
#  'Naturally',
#  'remain',
#  'leave',
#  'arrival',
#  'politeness',
#  'adjacent',
#  'refuge',
#  'vase',
#  'projecting',
#  'Fate',
#  'playful',
#  'impulse',
#  'overcame',
#  'unidentified',
#  'prank',
#  'insert',
#  'district',
#  'attorney',
#  'emerged',
#  'engagement',
#  'Culture',
#  'Forum',
#  'Spirit',
#  'Southland',
#  'president',
#  'forum',
#  'preside',
#  'brushed',
#  'arranged',
#  'painstakingly',
#  'selected',
#  'noting',
#  'footwear',
#  'dignity',
#  'mounted',
#  'rostrum',
#  'intellectuals',
#  'imagined',
#  'incident',
#  'aside',
#  'reflecting',
#  'wrecked',
#  'rested',
#  'culprit',
#  'vowed',
#  'actions',
#  'tragedies',
#  'commiserate',
#  'difficult',
#  'link',
#  'finds',
#  'association',
#  'invite',
#  'snobbishly',
#  'receive',
#  'Czarship',
#  'affected',
#  'values',
#  'reflected',
#  'glory',
#  'Angeles-Pasadena',
#  'scions',
#  'aristocratic',
#  'dominated',
#  'Budweisers',
#  'beer',
#  'derivation',
#  'Chalmers',
#  'underwear',
#  'Heinzes',
#  'forbears',
#  'founded',
#  'nationally',
#  'trade',
#  'pickles',
#  'hated',
#  'salons',
#  'aristocrats',
#  'seldom',
#  'remotely',
#  'connected',
#  'cinema',
#  'exclusive',
#  'midsts',
#  'King',
#  'Spain',
#  'Pickfair',
#  'Mary',
#  'Doug',
#  'beckoned',
#  'cross',
#  'barriers',
#  'separate',
#  'hoi-polloi',
#  'trump',
#  'matrimonial',
#  'opportunities',
#  'debs',
#  'educated',
#  'abroad',
#  'lenient',
#  'debutante',
#  'chi-chi',
#  'spend',
#  'cosy',
#  'chaperon',
#  'hotbed',
#  'gossip',
#  'precaution',
#  'whispered',
#  'alas',
#  'greeted',
#  'checked',
#  'apron',
#  'ladle',
#  "cook's",
#  'preparing',
#  'proceedings',
#  'giblet',
#  'gravy',
#  'asparagus',
#  'peas',
#  'sprig',
#  'mint',
#  'creamed',
#  'onions',
#  'mashed',
#  'potatoes',
#  'prepared',
#  'cooked',
#  'Hamlet',
#  'faced',
#  'agony',
#  "Beige's",
#  'tray',
#  'dish',
#  'ascending',
#  'scale',
#  'dressed',
#  'rang',
#  'instantly',
#  "Here's",
#  'household',
#  'grandmother',
#  'field',
#  'magically',
#  'Miranda',
#  'twined',
#  'murmuring',
#  'endearments',
#  'climbed',
#  'clutched',
#  'claiming',
#  'immediate',
#  'grounds',
#  'Somehow',
#  'managing',
#  'cool',
#  'poised',
#  "Won't",
#  'covered',
#  'mouthpiece',
#  'warmth',
#  'poise',
#  'crime',
#  'mostly',
#  "Devil's",
#  'Island',
#  'remoter',
#  'reaches',
#  'Siberia',
#  'promised',
#  'illustrate',
#  'breathed',
#  'completed',
#  'recognizing',
#  'caller',
#  'resumed',
#  'everyday',
#  'Soon',
#  'interrupted',
#  "Jennie's",
#  'holding',
#  'pretending',
#  "Miranda's",
#  'dumping',
#  'sugar',
#  'bowl',
#  'screeches',
#  'thuds',
#  'giggles',
#  'Under',
#  'reasonably',
#  'remind',
#  'Hank',
#  'shrewdly',
#  'vacated',
#  'gainer',
#  'accepted',
#  'peace',
#  'quiet',
#  'carrying',
#  'Resolving',
#  'formidable',
#  'demanding',
#  'staring',
#  'dismay',
#  'woolgather',
#  'month',
#  'indebted',
#  'shop',
#  'dentist',
#  'plumber',
#  'sitter',
#  'choice',
#  'yellow',
#  'amazingly',
#  'expert',
#  'narrow',
#  'ties',
#  'lapels',
#  'swatches',
#  "men's",
#  'editor',
#  'tremendous',
#  'circulation',
#  'Nebraska',
#  'Wyoming',
#  'heiress',
#  'cattle',
#  'baron',
#  'millionaire',
#  'bank',
#  'roll',
#  'dabbler',
#  'patronized',
#  'Greenwich',
#  'artists',
#  'awhile',
#  'decided',
#  'lavish',
#  'duly',
#  'recorded',
#  'newspapers',
#  'investigating',
#  'regions',
#  'suburbia',
#  'surrounding',
#  'schools',
#  'abundance',
#  'bound',
#  'dreary',
#  'housewives',
#  'dull',
#  'People',
#  'Who',
#  'Things',
#  'admired',
#  'escape',
#  'uneasiness',
#  'centuries-old',
#  'restored',
#  'guided',
#  'eminent',
#  'architect',
#  'updated',
#  "gourmet's",
#  'dust',
#  'anywhere',
#  'blocks',
#  'block',
#  'adjusted',
#  'parents',
#  'consequences',
#  'considered',
#  'violently',
#  'nonconformist',
#  'filling',
#  'furniture',
#  'paintings',
#  'objects',
#  'expensive',
#  'necessarily',
#  'valuable',
#  'flaunted',
#  'independence',
#  'rebelling',
#  'colors',
#  'bright',
#  'pinks',
#  'plaids',
#  'vivid',
#  'stripes',
#  'wore',
#  'solid',
#  'unrelieved',
#  'blonde',
#  'strongly',
#  'SS.',
#  'dislike',
#  'perfect',
#  'actors',
#  'handed',
#  'fat',
#  'talent',
#  'competently',
#  'understatement',
#  'Practically',
#  'enthusiasm',
#  'discussing',
#  'reverence',
#  "Fran's",
#  'Baccarat',
#  'Steuben',
#  'Madame',
#  'Alexander',
#  'wine',
#  'pot',
#  'marinated',
#  'brandy',
#  "Koussevitzky's",
#  'cousin',
#  'intimate',
#  'puzzling',
#  'inhabitants',
#  'unreal',
#  'Besides',
#  'drowned',
#  'melted',
#  'marshmallows',
#  'minimum',
#  'ruefulness',
#  'souffle',
#  'collapsed',
#  'Anyone',
#  'knows',
#  'red-blooded',
#  'react',
#  'catastrophe',
#  'honest',
#  'yelled',
#  'slammed',
#  'valueless',
#  'astringency',
#  'Gwen',
#  'Cafritz',
#  "Francesca's",
#  'Perle',
#  'Mesta',
#  'habitual',
#  'committee',
#  'chairmen',
#  'managed',
#  'elected',
#  'co-chairmen',
#  'equal',
#  'bosses',
#  'civic',
#  'launched',
#  'inseparable',
#  'fond',
#  'keen',
#  'rivals',
#  'leadership',
#  'bitterly',
#  'unfunnily',
#  'sarcastic',
#  'learning',
#  'drive',
#  'slick',
#  'golden',
#  'toast',
#  'ultra-modern',
#  'decoration',
#  'appointments',
#  'complement',
#  'raw',
#  'silk',
#  'matched',
#  'housepaint',
#  'shapeless',
#  'frozen',
#  'stick',
#  'distinguished',
#  'indistinguishable',
#  'communications',
#  'finite',
#  'developed',
#  'hair-trigger',
#  'deference',
#  'country-squirehood',
#  'missed',
#  'sincere',
#  'too-hearty',
#  'handclasp',
#  'urgent',
#  'acknowledged',
#  'introduction',
#  'pressing',
#  'gazed',
#  'misty-eyed',
#  'unadulterated',
#  'total',
#  'credited',
#  'leaping',
#  'cigarettes',
#  'plates',
#  'glasses',
#  'bake',
#  'shops',
#  'Sanitary',
#  'Bake',
#  'Shops',
#  'Pioneers',
#  'wondered',
#  'homesteads',
#  'odd',
#  'establish',
#  'suburban',
#  'off-duty',
#  'gardeners',
#  'parent-teacher',
#  'conferences',
#  'Mister',
#  '$85,000',
#  'yearly',
#  'ingratiating',
#  'gracious',
#  'estimation',
#  'Daphne',
#  'du',
#  'Maurier',
#  'Reverently',
#  'opinions',
#  'prove',
#  'Becoming',
#  'lunchtime',
#  'tasks',
#  'plans',
#  'beds',
#  'maybe',
#  'remembered',
#  'banana',
#  'Bananas',
#  'shouted',
#  'supposed',
#  'cereal',
#  'dug',
#  "devil's-food",
#  'icing',
#  'rule',
#  'garlic',
#  'stunned',
#  'dearth',
#  'thrills',
#  'Mama',
#  'providing',
#  'closed',
#  'stretched',
#  'forth',
#  'arms',
#  'Take',
#  'paradise',
#  'furious',
#  'unparalleled',
#  'intrusion',
#  'enterprise',
#  'dared',
#  'demand',
#  'snoop',
#  'disbursements',
#  'confidential',
#  'agreements',
#  'historic',
#  'three-hour',
#  'coast-to-coast',
#  'broadcast',
#  'Father',
#  'Coughlin',
#  'pre-empting',
#  'Merry-go-round',
#  'Bowes',
#  'shows',
#  'White',
#  'despot',
#  'yore',
#  'diary',
#  'raiding',
#  'larder',
#  'ransacking',
#  'lingerie',
#  'impassioned',
#  'civil',
#  'created',
#  'landslide',
#  'correspondence',
#  'sponsor',
#  'replacing',
#  'permanent',
#  'basis',
#  'defenseless',
#  'dictator',
#  'bold',
#  'banks',
#  'barbarian',
#  'hordes',
#  'Russian',
#  'Communism',
#  'Athens',
#  'mighty',
#  'sacking',
#  'despoiling',
#  'Bolshevistic',
#  'Soak',
#  'unspeakable',
#  'siege',
#  'lasting',
#  'announced',
#  'debt',
#  'excess',
#  'aloof',
#  'iniquitous',
#  'practices',
#  'paying',
#  'taxes',
#  'salary',
#  'legally',
#  'inherited',
#  "Morris'",
#  'relict',
#  'bill',
#  'astronomical',
#  'proportions',
#  'fraction',
#  'hard-come-by',
#  'savings',
#  'reprimanded',
#  'radical',
#  'leftist',
#  'Republic',
#  'Yorker',
#  'Time',
#  'Christian',
#  'Monitor',
#  'citizen',
#  'declared',
#  'income',
#  'unconstitutional',
#  'litigation',
#  'costly',
#  'seemingly',
#  'fought',
#  'tigress',
#  'appealed',
#  '1937',
#  'Roosevelt',
#  'henchmen',
#  'dirty',
#  'pack',
#  'highest',
#  'tribunal',
#  'land',
#  'defeat',
#  'Presidential',
#  'coercion',
#  'poisoning',
#  'courtiers',
#  'toadies',
#  'sycophants',
#  'bench',
#  'far-reaching',
#  'discourage',
#  'lawyer',
#  'Portia',
#  'unanimously',
#  'voted',
#  'Again',
#  'persona',
#  'grata',
#  'staunch',
#  'thinkers',
#  'jurisprudence',
#  'Charles',
#  'Evans',
#  'Hughes',
#  'limitations',
#  'exceeded',
#  'logic',
#  'litigant',
#  'Albert',
#  'Einstein',
#  'workings',
#  "woman's",
#  'amaze',
#  'Ford',
#  'utterly',
#  'astounding',
#  'Heywood',
#  'Broun',
#  'Belle',
#  'thinker',
#  'Caligula',
#  'concede',
#  'foresight',
#  'patriotism',
#  'resemble',
#  'ancient',
#  'Babylon',
#  'Nineveh',
#  'costs',
#  'prohibitive',
#  'crippling',
#  'fines',
#  'addition',
#  'usurious',
#  'unpaid',
#  'debts',
#  'claimed',
#  'blow',
#  'Nor',
#  'Manny',
#  'notoriety',
#  'enemies',
#  'level',
#  'charges',
#  'reactionary',
#  'robber',
#  'baroness',
#  'traitor',
#  'Traitor',
#  'point',
#  'ere',
#  'Committee',
#  'Un-American',
#  'Activities',
#  'Minute',
#  'Women',
#  'Economic',
#  'Council',
#  'notable',
#  'watchdog',
#  'organizations',
#  "Hollywood's",
#  'bulwark',
#  'communism',
#  'single-handedly',
#  'creeping',
#  'socialism',
#  'insuperable',
#  'Fascio-Communist',
#  'troops',
#  'NRA',
#  'PWA',
#  'WPA',
#  'CCC',
#  'twenty-two',
#  'mercenaries',
#  'employed',
#  'secretly',
#  'transparent',
#  'ruse',
#  'regular',
#  'checks',
#  'suffered',
#  'drastically',
#  'Even',
#  'genius',
#  'throwing',
#  'worth',
#  'expected',
#  'livelihood',
#  'imperilled',
#  'sweeping',
#  'distractions',
#  'conducive',
#  'Oscar',
#  'winning',
#  'performances',
#  'somehow',
#  'pressures',
#  'unflagging',
#  'effort',
#  'devotion',
#  'achieved',
#  'world-renowned',
#  'casting',
#  'vote',
#  'study',
#  'mile',
#  'thespians',
#  'forty',
#  'fifty',
#  'co-star',
#  'helpmate',
#  'patient',
#  'helpful',
#  'apologetic',
#  'indulged',
#  'outbursts',
#  'temperament',
#  'profanity',
#  'blaming',
#  'sulks',
#  'occasions',
#  'storming',
#  'finances',
#  'privileged',
#  'salted',
#  'servants',
#  'bills',
#  'tailor',
#  'Athletic',
#  'Club',
#  'gift',
#  'third',
#  'anniversary',
#  'dislocated',
#  'jaw',
#  'monies',
#  'dissipated',
#  'gaming',
#  'carousing',
#  'More',
#  'confronted',
#  'gamblers',
#  'loan',
#  'sharks',
#  'gangsters',
#  'thugs',
#  'existed',
#  'repay',
#  "husband's",
#  'staggering',
#  'losses',
#  'shuddered',
#  'sinister',
#  'strange',
#  'commonest',
#  'accents',
#  'telephoned',
#  'announce',
#  'sired',
#  'unborn',
#  'deepest',
#  'maternal',
#  'instincts',
#  'bled',
#  'darling',
#  'pink',
#  'bundles',
#  'heaven',
#  'proudly',
#  'Ah',
#  'ungallant',
#  'untrue',
#  'retort',
#  'abundantly',
#  'precious',
#  'wiser',
#  'summers',
#  'camp',
#  'Friends',
#  'irritable',
#  'neglected',
#  'anyhow',
#  'God',
#  'infinite',
#  'wisdom',
#  'wants',
#  'inexplicable',
#  'lapses',
#  'memory',
#  'works',
#  'Yet',
#  'adored',
#  'absences',
#  'coldness',
#  'indifference',
#  'slights',
#  'humiliated',
#  'parties',
#  'Trianon',
#  'Suite',
#  ...]

# %%
fd_w_humor.max()
# Out:
# ','

# %%
fd_w_humor.freq('the')
# Out:
# 0.04286702005070293

# %%
fd_w_humor.get('the')
# Out:
# 930

# %%
930/21695
# Out:
# 0.04286702005070293

# %% [markdown]
# ### Conditional Frequency Dist

# %%
l1 = [('cat1', 'good'), ('cat2', 'bad'), ('cat1', 'good')]

# %%
cfd = ConditionalFreqDist(l1)

# %%
cfd
# Out:
# <ConditionalFreqDist with 2 conditions>

# %%
cfd['cat1']
# Out:
# FreqDist({'good': 2})

# %%
cfd = ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre)
)
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions = genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %% [markdown]
# ### Names and Last Letter

# %%
from nltk.corpus import names

# %%
l_names = ([('male', name[-1]) for name in names.words('male.txt')] +
            [('female', name[-1]) for name in names.words('female.txt')])

# %%
cfd_names = ConditionalFreqDist(l_names)

# %%
cfd_names
# Out:
# <ConditionalFreqDist with 2 conditions>

# %%
cfd_names.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
